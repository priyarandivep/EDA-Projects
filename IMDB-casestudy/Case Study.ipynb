# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('IMDB-Movie-Data.csv')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (1000, 12)

# %% [markdown]
# ##### A dataset contains 1000 rows and 12 columns.

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# #####  The memory usage of dataset is 93.9 KB . There are some null value present in Revenue and Metascore columns. we have to handle those null values. There are some columns are categorical and some are numerical columns

# %% [markdown]
# ### 5. Check Missing Values In The Dataset

# %%
df.isnull().sum()/len(df)*100
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
ax= plt.axes()

sns.heatmap(df.isnull(), cbar= False, ax= ax)
plt.show()

# %% [markdown]
# ### 6. Drop All The Missing Values

# %%
df.dropna(inplace= True)

# %%
df.reset_index(drop= True, inplace= True)

# %%
df
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 833   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834   995                 Project X                    Comedy
# 835   997           Hostel: Part II                    Horror
# 836   998    Step Up 2: The Streets       Drama,Music,Romance
# 837  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 7. Check For Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### There are no duplicate values present in our dataset

# %% [markdown]
# ### 8. Get Overall Statistics About The DataFrame

# %%
df.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# #####  From the above statistical information, we can say that:
# ##### 1.  Rank  column - mean is greater than median hence it is slightly right skewed
# ##### 2.  Runtime-  mean is greater than median hence it is slightly right skewed
# ##### 3. Rating- mean is equal  to median  it is normally distributed
# ##### 4. Revenue- mean is greater than median hence it is rightt skewed
# ##### 5. Metascore-  mean and median are equal it is normally distributed

# %% [markdown]
# ### 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
df[df["Runtime (Minutes)"]>=180]["Title"]
# Out:
# 71     The Wolf of Wall Street
# 77           The Hateful Eight
# 277             La vie d'Adèle
# Name: Title, dtype: object

# %% [markdown]
# ##### Above are the movies who have runtime greater than and equal to 180 Minutes

# %% [markdown]
# ### 10. In Which Year There Was The Highest Average Voting?

# %%
df.groupby("Year")["Votes"].mean()
# Out:
# Year
# 2006    277232.219512
# 2007    266530.704545
# 2008    266580.145833
# 2009    267180.577778
# 2010    261082.929825
# 2011    259254.736842
# 2012    290861.483871
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %%
plt.figure(figsize= (9,5))
sns.barplot(x="Year", y=  "Votes", data= df)
plt.show()

# %% [markdown]
# ### 11. In Which Year There Was The Highest Average Revenue?

# %%
df.groupby('Year')['Revenue (Millions)'].mean()
# Out:
# Year
# 2006     87.255610
# 2007     93.074091
# 2008     97.525417
# 2009    115.742000
# 2010    105.081579
# 2011     93.703333
# 2012    110.103065
# 2013     88.084643
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# ### 12. Find The Average Rating For Each Director

# %%
df.groupby("Director")["Rating"].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam McKay             7.00
# Adam Shankman          6.30
# Adam Wingard           5.90
#                        ...
# Xavier Dolan           8.10
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 524, dtype: float64

# %% [markdown]
# ### 13. Display Top 10 Lengthy Movies Title and Runtime

# %%
a=df.sort_values("Runtime (Minutes)", ascending= False).loc[:, ['Title', "Runtime (Minutes)"]].head(10)
a
# Out:
#                                         Title  Runtime (Minutes)
# 77                          The Hateful Eight                187
# 71                    The Wolf of Wall Street                180
# 277                            La vie d'Adèle                180
# 239                               Cloud Atlas                172
# 380                                  3 Idiots                170
# 64   Pirates of the Caribbean: At World's End                169
# 31                               Interstellar                169
# 242         The Hobbit: An Unexpected Journey                169
# 377       The Curious Case of Benjamin Button                166
# 110           Transformers: Age of Extinction                165

# %%
sns.barplot(y= a["Title"], x= a['Runtime (Minutes)'])
# Out:
# <AxesSubplot:xlabel='Runtime (Minutes)', ylabel='Title'>

# %% [markdown]
# ### 14. Display Number of Movies Per Year

# %%
sns.countplot(x= 'Year', data= df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
df.groupby('Year')['Year'].value_counts()
# Out:
# Year  Year
# 2006  2006     41
# 2007  2007     44
# 2008  2008     48
# 2009  2009     45
# 2010  2010     57
# 2011  2011     57
# 2012  2012     62
# 2013  2013     84
# 2014  2014     93
# 2015  2015    109
# 2016  2016    198
# Name: Year, dtype: int64

# %% [markdown]
# ### 15. Find Most Popular Movie Title (Higest Revenue)

# %%
df.sort_values("Revenue (Millions)", ascending= False).loc[:, ["Title", "Revenue (Millions)"]].head(1)
# Out:
#                                          Title  Revenue (Millions)
# 41  Star Wars: Episode VII - The Force Awakens              936.63

# %%
df[df["Revenue (Millions)"]==  (df["Revenue (Millions)"].max())]["Title"]
# Out:
# 41    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# ### 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
a=df.sort_values("Rating", ascending= False).loc[:, ["Title", "Director", "Rating"]].head(10)
a
# Out:
#                      Title                          Director  Rating
# 45         The Dark Knight                 Christopher Nolan     9.0
# 69               Inception                 Christopher Nolan     8.8
# 31            Interstellar                 Christopher Nolan     8.6
# 221       The Intouchables                   Olivier Nakache     8.6
# 85           Kimi no na wa                    Makoto Shinkai     8.6
# 108  The Dark Knight Rises                 Christopher Nolan     8.5
# 832       Taare Zameen Par                        Aamir Khan     8.5
# 117               Whiplash                   Damien Chazelle     8.5
# 88            The Departed                   Martin Scorsese     8.5
# 420    The Lives of Others  Florian Henckel von Donnersmarck     8.5

# %%
sns.barplot(y= a["Title"], x= a["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Title'>

# %% [markdown]
# ### 17. Display Top 10 Highest Revenue Movie Titles

# %%
df.sort_values("Revenue (Millions)", ascending= False).loc[:, ["Title", "Revenue (Millions)"]].head(10)
# Out:
#                                           Title  Revenue (Millions)
# 41   Star Wars: Episode VII - The Force Awakens              936.63
# 76                                       Avatar              760.51
# 74                               Jurassic World              652.18
# 65                                 The Avengers              623.28
# 45                              The Dark Knight              533.32
# 11                                    Rogue One              532.17
# 104                                Finding Dory              486.29
# 83                      Avengers: Age of Ultron              458.99
# 108                       The Dark Knight Rises              448.13
# 502             The Hunger Games: Catching Fire              424.65

# %% [markdown]
# ### 18. Find Average Rating of Movies Year Wise

# %%
a=df.groupby('Year')["Rating"].mean()
a
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
sns.barplot(x= a.index, y= a.values)
plt.show()

# %% [markdown]
# ### 9. Does Rating Affect The Revenue?

# %%
sns.scatterplot(x= "Rating", y= "Revenue (Millions)", data= df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Revenue (Millions)'>

# %% [markdown]
# ### 20. Classify Movies Based on Ratings [Excellent, Good and Average]

# %%
def rating_cat(x):
    if x>= 7:
        return "Excellent"
    elif x<7.0 and x>=5.0:
        return "Good"
    else:
        return "Average"

# %%
df["Rating_cat"]= df["Rating"].map(rating_cat)

# %%
df
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 833   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 834   995                 Project X                    Comedy
# 835   997           Hostel: Part II                    Horror
# 836   998    Step Up 2: The Streets       Drama,Music,Romance
# 837  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 21. Count Number of Action Movies

# %%
df[df['Genre'].str.contains("Action")]['Title'].count()
# Out:
# 277

# %% [markdown]
# ### 22. Find Unique Values From Genre

# %%
a= df["Genre"]
a
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 833     Action,Adventure,Horror
# 834                      Comedy
# 835                      Horror
# 836         Drama,Music,Romance
# 837       Comedy,Family,Fantasy
# Name: Genre, Length: 838, dtype: object

# %%
 c=[]
for i in a.values:
   
    d=i.split(",")
    c.append(d)

# %%
c
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Action', 'Adventure', 'Comedy'],
# ...

# %%
un= []
for i in c:
    for it in i:
        if it not in un:
            un.append(it)

# %%
un
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Western',
#  'Crime',
#  'War',
#  'Musical',
#  'Sport']
